# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
from time import sleep
import json

# %%
driver = webdriver.Chrome()
driver.get("https://www.oddsportal.com/rugby-union/world/united-rugby-championship/results/")
sleep(30)

# %%
gameRows = driver.find_elements(By.XPATH,'//div[@class="group flex"]')
gameRows
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="15eac1189296da1cc230a8409ec6764d", element="f.F607C0A62DE8201D2B4F77D071B067B9.d.F243C33EEFB29B2E8B292C7EEC28B8C5.e.128")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="15eac1189296da1cc230a8409ec6764d", element="f.F607C0A62DE8201D2B4F77D071B067B9.d.F243C33EEFB29B2E8B292C7EEC28B8C5.e.129")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="15eac1189296da1cc230a8409ec6764d", element="f.F607C0A62DE8201D2B4F77D071B067B9.d.F243C33EEFB29B2E8B292C7EEC28B8C5.e.130")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="15eac1189296da1cc230a8409ec6764d", element="f.F607C0A62DE8201D2B4F77D071B067B9.d.F243C33EEFB29B2E8B292C7EEC28B8C5.e.131")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="15eac1189296da1cc230a8409ec6764d", element="f.F607C0A62DE8201D2B4F77D071B067B9.d.F243C33EEFB29B2E8B292C7EEC28B8C5.e.132")>,
# ...

# %%
len(gameRows)
# Out:
# 46

# %%
rowData = [row.text.split("\n") for row in gameRows]

# %%
for row in rowData:
    if row[2] == "\u2013":
        try:
            data.update({row[1]+" vs. "+row[3]:{
                                        "Team1_Odds":row[4],
                                        "Team2_Odds":row[5],
                                        "No. of Bookmakers":row[6]
                                        }})
        except:
            continue
    else:
        try:
            data.update({row[1]+" vs. "+row[5]:{
                                        "Team1_Odds":row[6],
                                        "Team2_Odds":row[7],
                                        "No. of Bookmakers":row[8]
                                        }})
        except:
            continue

# %%
for i in rowData:
    print(len(i))
# Out:
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10
# 10

# %%
urc_24_25 = pd.DataFrame(rowData, 
                         columns=['aus_time', 'home_team', 'home_score', 'dash', 'away_score', 
                                  'away_team', 'home_win_odds', 'draw_odds', 'away_win_odds', 'n_bookies'])

urc_24_25.drop(columns=['dash'], inplace=True)

urc_24_25
# Out:
#    aus_time         home_team home_score away_score         away_team  \
# 0     05:35     Cardiff Rugby         21         19            Ulster
# 1     05:35          Connacht         31          7           Dragons
# 2     03:15          Leinster         24          6             Lions
# 3     01:00           Ospreys         22         13         Edinburgh
# 4     01:00            Sharks         41         24           Munster
# 5     22:45          Stormers         17         28  Glasgow Warriors
# 6     05:35          Benetton         15         17             Bulls
# 7     05:35          Scarlets         30          8             Zebre
# 8     05:35          Connacht         12         33          Leinster
# 9     05:35           Dragons         21         31          Benetton
# 10    03:15         Edinburgh         27          8     Cardiff Rugby
# 11    03:00          Stormers         34         19           Munster
# ...

# %%
urc_24_25.to_csv("urc_25_odds.csv", index=False)

# %%
# Out:
# 30

# %%
driver.close()
